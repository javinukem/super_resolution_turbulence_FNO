# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import sys
import os

sys.path.append(os.path.abspath(".."))  # This brings 'src' into the path

# %%
df = pd.read_csv("fno_eval_results.csv")
x = "modes"
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x=x, y="val_loss", hue="last_layer_constraint", marker="o")

# Ensure x-axis only shows integer ticks
x_ticks = sorted(df[x].unique())
plt.xticks(x_ticks)
plt.yscale("log")
plt.xlabel(x)
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Residual Blocks (Grouped by Modes)")
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
idx = df["val_loss"].idxmin()  # Get the index of the minimum val_loss
print(df.loc[idx])  # Print the entire row corresponding to that index
# Out:
# folder                   m16_nc32_res3_op2_ac0_lk3lcexp
# val_loss                                       0.001245
# time                                           0.082377
# modes                                                16
# n_channels                                           32
# n_residual_blocks                                     3
# n_operator_blocks                                     2
# apply_constraint                                  False
# shifting_modes                                        1
# last_layer_kernel                                     3
# last_layer_constraint                               exp
# Name: 0, dtype: object

# %%
x = "modes"
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x=x, y="val_loss", hue="n_channels", marker="o")

# Ensure x-axis only shows integer ticks
x_ticks = sorted(df[x].unique())
plt.xticks(x_ticks)
plt.yscale("log")
plt.xlabel(x)
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Residual Blocks (Grouped by Modes)")
plt.grid(False)
plt.tight_layout()
plt.show()

# %%
x = "modes"
plt.figure(figsize=(8, 6))
sns.lineplot(data=df, x=x, y="val_loss", hue="n_operator_blocks", marker="o")

# Ensure x-axis only shows integer ticks
x_ticks = sorted(df[x].unique())
plt.xticks(x_ticks)
plt.yscale("log")
plt.xlabel(x)
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Residual Blocks (Grouped by Modes)")
plt.grid(False)
plt.tight_layout()
plt.show()
