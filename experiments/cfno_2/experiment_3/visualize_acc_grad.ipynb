# %%
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
data = np.load(os.path.abspath("/export/data/jalegria/experiments/experiment_3/acc_grad/losses.npz"), allow_pickle=True)
losses = data.files

# %%
print(losses)
print(np.shape(data["train_losses"]))
# Out:
# ['acc_grads', 'train_losses', 'test_losses', 'times']
# (5, 50)

# %%
fig, ax = plt.subplots()
acc_grads = data['acc_grads']
ax.plot(data['train_losses'].T, label = acc_grads)
ax.legend()
